# %%
# -*- coding: utf-8 -*-
"""
Created on Thu Sep 22 12:25:35 2022

# %%
@author: emeli
"""

# %%
def reflex1(temperature,exposition_time,sensibility) :
    #this is the "global function" with only one system
    
    #add a loop using the exposition_time
    #sensibility is the level of pain (depending on the person) at wich point he.she removes the foot
    #pressure is a boolean (True or False), pressure of the environment, forcing the foot to remain in the fire
    
    Pain=0
    t=0
   
    while Pain<=sensibility and t<exposition_time:
            Pain=Pain*temperature+t
            print(Pain)
            t+=1
    else :
        print('I remove my foot at',t)

# %%
def reflex2(temperature,time,distance,sensibility) :
    #this function still doesn't work, I keep having mistakes and I don't know if they are due to Spyder unmatches 
    #this function should have 3 systems (pain receptors, Nerves, CNS :central nervous system,Motoneurons,Foot)
    #we can consider the nerves/motoneurons as outputs of some systems
    #distance in centimeters
    #for the foot : input could be fire (temperature) and the output "nerve is activated"
    body_temperature=37
    threshold=75
    motor_nerve=False
    sensitive_nerve=True
    Remove=False
    
    def foot(situation,receptors_on=False):
       if situation==1: #outcoming information to the CNS
           if temperature>body_temperature:
                receptors_on=True
                if receptors_on:
                    AP=time*((temperature-body_temperature)-distance*100 #As many action potentials sent as degrees difference
                    #20 degrees differences between foot and fire = 200 AP sent by the nerve 
                        if AP>(threshold*100):
                             nerves(1)                 
        else : #incoming information from the CNS
            if motor_nerve :
                Remove=True
    
    def nerves(nerve_type):
        if nerve_type=1: #we are in a sensitive_nerve = incoming information
           sensitive_nerve=True
        else : #we are in a motor_nerve, outcoming information :
            motor_nerve=True
            foot(2,receptors_on=False)
        
    def CNS(): #central nervous system
        decision=random()
            if decision<0.95 :
                 #for some reason, in 5% of time the subject choose to let his foot for challenge
                nerves(2)

# %%
    
    foot(1,receptors_on=False) #to launch all the process
    if remove=True
        print('I remove my foot at',t)
    else :
        print('I kept my foot in the fire')
