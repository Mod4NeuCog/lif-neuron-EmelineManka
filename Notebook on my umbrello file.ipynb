# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# I did not put aaaall the parameters that I use in Python because it seemed just too big.

# %% [markdown]
# For the function of the motherclass, I actually have more than one function. But the update membrane potential uses several little functions (that you will see on Python, like dV, dVdt) and since they are not called and just automatically used, i defined them in the squeletton of the function updatemembranepotential.

# %% [markdown]
# For the subclasses, I created specific parameters like "Number of specialized organite". Meaning that it could exist a specific structure in the pyramidal neuron, that changes the membrane potential by affecting the updatemembranepotential final value.

# %% [markdown]
# Same principle on the other class
