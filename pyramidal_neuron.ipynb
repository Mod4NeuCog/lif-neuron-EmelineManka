# %%
# -*- coding: utf-8 -*-
"""
Created on Wed Oct 12 15:00:30 2022

# %%
@author: emeli
"""

# %%
from Neuron_cell_type import Neuron_cell_type 
    
class pyramidal_neuron(Neuron_cell_type):
    
    def __init__(self):
        super(Neuron_cell_type, self).__init__() #super allows to recall the init function of the motherclass if when we create specific parameters in the child classes 
        self.number_organite=195 #i tried to put random()
        
    def organite_function(self) :
        if self.number_organite>200:
            self.V_reset=-80 #We assume

# %% [markdown]
# I tried to use random() to actually have different values of "number_organite" each time...but i need to import it from math and when I wanted to convert my file into p2j it didn't work :

# %% [markdown]
# ![image.png](attachment:image.png)
