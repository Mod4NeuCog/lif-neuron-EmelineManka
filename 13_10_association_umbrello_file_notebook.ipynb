# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Neuron class** Here I created two functions: getting hungry, that makes the stomach value decreasing, and get_fed, which does the opposite.

# %% [markdown]
# **Glial_cell class** The value given by get fed function is from the glial cell class, it's nutrients. And it's returned by the function get meal.
